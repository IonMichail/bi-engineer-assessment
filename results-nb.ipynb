# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
import duckdb
import pandas as pd

# %load_ext sql
conn = duckdb.connect("casino.db")
# %sql conn --alias duckdb

# %%
# %sql SELECT * FROM metrics;
# Out:
#             Date Country Sex AgeGroup  VIPStatus CasinoManufacturerName  \
# 0     2025-01-01     NZD   M    21-26     BRONZE              Evolution
# 1     2025-01-01     NZD   M    21-26     BRONZE                Playson
# 2     2025-01-01     NZD   M    21-26     BRONZE         BackseatGaming
# 3     2025-01-01     NZD   M    21-26     BRONZE                PlayNGo
# 4     2025-01-01     NZD   M    21-26     BRONZE                Hacksaw
# ...          ...     ...  ..      ...        ...                    ...
# 31400 2025-05-27     NZD   M      50+      ELITE              Evolution
# 31401 2025-05-27     NZD   M      50+      ELITE     Stormcraft Studios
# 31402 2025-05-27     NZD   F      50+  POTENTIAL          PragmaticPlay
# 31403 2025-05-27     NZD   F      50+  POTENTIAL     Stormcraft Studios
# 31404 2025-05-27     NZD   F      50+  POTENTIAL     Stormcraft Studios
#
#       CasinoProviderName           GGR       Returns
# ...
